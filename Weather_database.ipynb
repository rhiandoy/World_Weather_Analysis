# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import time
from datetime import datetime

# import the requests library
import requests

# import the API key
from config import weather_api_key

# %%
# Create a set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Get the nearest city using citipy module
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=12dc0e98aa28348d65497aae53a01a6f

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sioux lookout
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | hovd
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | aklavik
# Processing Record 10 of Set 1 | olafsvik
# Processing Record 11 of Set 1 | garowe
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | naze
# Processing Record 14 of Set 1 | bambous virieux
# Processing Record 15 of Set 1 | vytegra
# Processing Record 16 of Set 1 | kencong
# Processing Record 17 of Set 1 | huarmey
# Processing Record 18 of Set 1 | labuhan
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | biak
# Processing Record 21 of Set 1 | toamasina
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | amapa
# Processing Record 25 of Set 1 | sunel
# Processing Record 26 of Set 1 | college
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | lebu
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | namibe
# Processing Record 32 of Set 1 | makakilo city
# Processing Record 33 of Set 1 | souillac
# Processing Record 34 of Set 1 | kimbe
# Processing Record 35 of Set 1 | sakaiminato
# Processing Record 36 of Set 1 | bengkulu
# Processing Record 37 of Set 1 | uliesti
# Processing Record 38 of Set 1 | isangel
# Processing Record 39 of Set 1 | yumen
# Processing Record 40 of Set 1 | el alto
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | laibin
# Processing Record 43 of Set 1 | skibbereen
# Processing Record 44 of Set 1 | raudeberg
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | mwinilunga
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | salalah
# Processing Record 3 of Set 2 | komsomolskiy
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 2 | sorland
# Processing Record 7 of Set 2 | vestmannaeyjar
# Processing Record 8 of Set 2 | san patricio
# Processing Record 9 of Set 2 | atasu
# Processing Record 10 of Set 2 | pingliang
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | cherskiy
# Processing Record 13 of Set 2 | airai
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | cradock
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | taoudenni
# Processing Record 20 of Set 2 | mahebourg
# Processing Record 21 of Set 2 | sembe
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | ponta do sol
# Processing Record 24 of Set 2 | half moon bay
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | cabo san lucas
# Processing Record 27 of Set 2 | mount isa
# Processing Record 28 of Set 2 | nikolskoye
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | auki
# Processing Record 32 of Set 2 | korla
# Processing Record 33 of Set 2 | quatre cocos
# Processing Record 34 of Set 2 | marawi
# Processing Record 35 of Set 2 | cabedelo
# Processing Record 36 of Set 2 | surab
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | baykit
# Processing Record 39 of Set 2 | pacific grove
# Processing Record 40 of Set 2 | palmerston
# Processing Record 41 of Set 2 | kollam
# Processing Record 42 of Set 2 | hamilton
# Processing Record 43 of Set 2 | dingle
# Processing Record 44 of Set 2 | lompoc
# Processing Record 45 of Set 2 | leningradskiy
# Processing Record 46 of Set 2 | port-gentil
# Processing Record 47 of Set 2 | qaanaaq
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | pevek
# Processing Record 50 of Set 2 | jalu
# Processing Record 1 of Set 3 | veinticinco de mayo
# Processing Record 2 of Set 3 | constitucion
# Processing Record 3 of Set 3 | sao geraldo do araguaia
# Processing Record 4 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 3 | jacksonville
# Processing Record 6 of Set 3 | guerrero negro
# Processing Record 7 of Set 3 | vila velha
# Processing Record 8 of Set 3 | fairbanks
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | semiletka
# Processing Record 11 of Set 3 | ranong
# Processing Record 12 of Set 3 | birao
# Processing Record 13 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 14 of Set 3 | bredasdorp
# Processing Record 15 of Set 3 | srednekolymsk
# Processing Record 16 of Set 3 | yinchuan
# Processing Record 17 of Set 3 | mayo
# Processing Record 18 of Set 3 | vao
# Processing Record 19 of Set 3 | gravdal
# Processing Record 20 of Set 3 | matelandia
# Processing Record 21 of Set 3 | gumdag
# Processing Record 22 of Set 3 | dongsheng
# Processing Record 23 of Set 3 | clyde river
# Processing Record 24 of Set 3 | bac lieu
# Processing Record 25 of Set 3 | banamba
# Processing Record 26 of Set 3 | portland
# Processing Record 27 of Set 3 | acapulco
# Processing Record 28 of Set 3 | itarema
# Processing Record 29 of Set 3 | puerto escondido
# Processing Record 30 of Set 3 | kribi
# Processing Record 31 of Set 3 | coquimbo
# Processing Record 32 of Set 3 | kapaa
# Processing Record 33 of Set 3 | severo-kurilsk
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | kruisfontein
# Processing Record 36 of Set 3 | ribeira grande
# Processing Record 37 of Set 3 | tautira
# Processing Record 38 of Set 3 | karpogory
# Processing Record 39 of Set 3 | charters towers
# Processing Record 40 of Set 3 | kikwit
# Processing Record 41 of Set 3 | kavaratti
# Processing Record 42 of Set 3 | minab
# Processing Record 43 of Set 3 | san cristobal
# Processing Record 44 of Set 3 | busselton
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | evensk
# Processing Record 47 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | aykhal
# Processing Record 49 of Set 3 | avera
# Processing Record 50 of Set 3 | lyubech
# Processing Record 1 of Set 4 | saryozek
# Processing Record 2 of Set 4 | cururupu
# Processing Record 3 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | tateyama
# Processing Record 6 of Set 4 | byron bay
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | smithers
# Processing Record 9 of Set 4 | luwuk
# Processing Record 10 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 4 | sitka
# Processing Record 12 of Set 4 | okhotsk
# Processing Record 13 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 4 | jamestown
# Processing Record 15 of Set 4 | talnakh
# Processing Record 16 of Set 4 | madimba
# Processing Record 17 of Set 4 | pangnirtung
# Processing Record 18 of Set 4 | tura
# Processing Record 19 of Set 4 | nabire
# Processing Record 20 of Set 4 | ola
# Processing Record 21 of Set 4 | lata
# Processing Record 22 of Set 4 | imbituba
# Processing Record 23 of Set 4 | mar del plata
# Processing Record 24 of Set 4 | deputatskiy
# Processing Record 25 of Set 4 | timizart
# Processing Record 26 of Set 4 | yazykovo
# Processing Record 27 of Set 4 | yaan
# Processing Record 28 of Set 4 | swan hill
# Processing Record 29 of Set 4 | concepcion del oro
# Processing Record 30 of Set 4 | yantal
# Processing Record 31 of Set 4 | kahului
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | luderitz
# Processing Record 34 of Set 4 | henties bay
# Processing Record 35 of Set 4 | lorengau
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | lavrentiya
# Processing Record 38 of Set 4 | nalut
# Processing Record 39 of Set 4 | mana
# Processing Record 40 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 4 | sonoita
# Processing Record 42 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 4 | iqaluit
# Processing Record 45 of Set 4 | port macquarie
# Processing Record 46 of Set 4 | victoria point
# Processing Record 47 of Set 4 | porto uniao
# Processing Record 48 of Set 4 | geraldton
# Processing Record 49 of Set 4 | yaring
# Processing Record 50 of Set 4 | viedma
# Processing Record 1 of Set 5 | amahai
# Processing Record 2 of Set 5 | mujiayingzi
# Processing Record 3 of Set 5 | sechura
# Processing Record 4 of Set 5 | borlange
# City not found. Skipping...
# Processing Record 5 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 5 | hambantota
# Processing Record 7 of Set 5 | severobaykalsk
# Processing Record 8 of Set 5 | klyuchi
# Processing Record 9 of Set 5 | jalingo
# Processing Record 10 of Set 5 | saldanha
# Processing Record 11 of Set 5 | ouallam
# Processing Record 12 of Set 5 | teya
# Processing Record 13 of Set 5 | zhangye
# Processing Record 14 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 15 of Set 5 | doka
# Processing Record 16 of Set 5 | gat
# Processing Record 17 of Set 5 | kholuy
# Processing Record 18 of Set 5 | chushan
# Processing Record 19 of Set 5 | praya
# Processing Record 20 of Set 5 | kyabe
# Processing Record 21 of Set 5 | lapua
# Processing Record 22 of Set 5 | aksu
# Processing Record 23 of Set 5 | ponta delgada
# Processing Record 24 of Set 5 | yerbogachen
# Processing Record 25 of Set 5 | tessalit
# Processing Record 26 of Set 5 | nelson bay
# Processing Record 27 of Set 5 | shonguy
# Processing Record 28 of Set 5 | vung tau
# Processing Record 29 of Set 5 | suzu
# City not found. Skipping...
# Processing Record 30 of Set 5 | boddam
# Processing Record 31 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 32 of Set 5 | praia da vitoria
# Processing Record 33 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 5 | dubrovnik
# Processing Record 35 of Set 5 | nyurba
# Processing Record 36 of Set 5 | thanh hoa
# Processing Record 37 of Set 5 | coruripe
# Processing Record 38 of Set 5 | bathsheba
# Processing Record 39 of Set 5 | porterville
# Processing Record 40 of Set 5 | polyarnyy
# Processing Record 41 of Set 5 | lagoa
# Processing Record 42 of Set 5 | moroni
# Processing Record 43 of Set 5 | arlit
# Processing Record 44 of Set 5 | umm lajj
# Processing Record 45 of Set 5 | comodoro rivadavia
# Processing Record 46 of Set 5 | kavieng
# Processing Record 47 of Set 5 | sainte-maxime
# Processing Record 48 of Set 5 | mendoza
# Processing Record 49 of Set 5 | cairns
# Processing Record 50 of Set 5 | angoche
# Processing Record 1 of Set 6 | imeni poliny osipenko
# Processing Record 2 of Set 6 | oberwart
# Processing Record 3 of Set 6 | nishihara
# Processing Record 4 of Set 6 | codrington
# Processing Record 5 of Set 6 | teneguiban
# City not found. Skipping...
# Processing Record 6 of Set 6 | cockburn town
# Processing Record 7 of Set 6 | victoria
# Processing Record 8 of Set 6 | sambava
# Processing Record 9 of Set 6 | hualmay
# Processing Record 10 of Set 6 | matara
# Processing Record 11 of Set 6 | ugoofaaru
# Processing Record 12 of Set 6 | seoul
# Processing Record 13 of Set 6 | burica
# City not found. Skipping...
# Processing Record 14 of Set 6 | sarkikaraagac
# Processing Record 15 of Set 6 | palu
# Processing Record 16 of Set 6 | grindavik
# Processing Record 17 of Set 6 | uthal
# Processing Record 18 of Set 6 | duz
# City not found. Skipping...
# Processing Record 19 of Set 6 | yulara
# Processing Record 20 of Set 6 | banda aceh
# Processing Record 21 of Set 6 | helena
# Processing Record 22 of Set 6 | tieling
# Processing Record 23 of Set 6 | flin flon
# Processing Record 24 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 25 of Set 6 | niimi
# Processing Record 26 of Set 6 | jardim
# Processing Record 27 of Set 6 | sao joao da barra
# Processing Record 28 of Set 6 | lazaro cardenas
# Processing Record 29 of Set 6 | kemin
# Processing Record 30 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 6 | mesetas
# Processing Record 32 of Set 6 | xuchang
# Processing Record 33 of Set 6 | turtkul
# City not found. Skipping...
# Processing Record 34 of Set 6 | bajo baudo
# City not found. Skipping...
# Processing Record 35 of Set 6 | purpe
# Processing Record 36 of Set 6 | fortuna
# Processing Record 37 of Set 6 | shimoda
# Processing Record 38 of Set 6 | belyy yar
# Processing Record 39 of Set 6 | marzuq
# Processing Record 40 of Set 6 | castro
# Processing Record 41 of Set 6 | yeppoon
# Processing Record 42 of Set 6 | tadine
# Processing Record 43 of Set 6 | kamaishi
# Processing Record 44 of Set 6 | lasa
# Processing Record 45 of Set 6 | saint-georges
# Processing Record 46 of Set 6 | georgetown
# Processing Record 47 of Set 6 | champerico
# Processing Record 48 of Set 6 | sakakah
# Processing Record 49 of Set 6 | roebourne
# Processing Record 50 of Set 6 | sola
# Processing Record 1 of Set 7 | verkh-usugli
# Processing Record 2 of Set 7 | kaitangata
# Processing Record 3 of Set 7 | mackenzie
# Processing Record 4 of Set 7 | piacabucu
# Processing Record 5 of Set 7 | tsiroanomandidy
# Processing Record 6 of Set 7 | longonjo
# Processing Record 7 of Set 7 | synya
# Processing Record 8 of Set 7 | yeniseysk
# Processing Record 9 of Set 7 | savannah bight
# Processing Record 10 of Set 7 | oudtshoorn
# Processing Record 11 of Set 7 | sao filipe
# Processing Record 12 of Set 7 | ust-tarka
# Processing Record 13 of Set 7 | husavik
# Processing Record 14 of Set 7 | ndende
# Processing Record 15 of Set 7 | inhambane
# Processing Record 16 of Set 7 | torbay
# Processing Record 17 of Set 7 | ambulu
# Processing Record 18 of Set 7 | whitehorse
# Processing Record 19 of Set 7 | maceio
# Processing Record 20 of Set 7 | port lincoln
# Processing Record 21 of Set 7 | port blair
# Processing Record 22 of Set 7 | changqing
# Processing Record 23 of Set 7 | kuryk
# Processing Record 24 of Set 7 | laguna
# Processing Record 25 of Set 7 | provideniya
# Processing Record 26 of Set 7 | unai
# Processing Record 27 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 28 of Set 7 | walvis bay
# Processing Record 29 of Set 7 | camopi
# Processing Record 30 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 31 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 7 | blyth
# Processing Record 33 of Set 7 | karpathos
# Processing Record 34 of Set 7 | krasnogorsk
# Processing Record 35 of Set 7 | rawson
# Processing Record 36 of Set 7 | rumoi
# Processing Record 37 of Set 7 | araguacu
# Processing Record 38 of Set 7 | zyryanovsk
# Processing Record 39 of Set 7 | ahipara
# Processing Record 40 of Set 7 | narsaq
# Processing Record 41 of Set 7 | tasiilaq
# Processing Record 42 of Set 7 | carnarvon
# Processing Record 43 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 7 | morant bay
# Processing Record 45 of Set 7 | caohai
# Processing Record 46 of Set 7 | pisco
# Processing Record 47 of Set 7 | george town
# Processing Record 48 of Set 7 | hofn
# Processing Record 49 of Set 7 | necochea
# Processing Record 50 of Set 7 | upington
# Processing Record 1 of Set 8 | chokurdakh
# Processing Record 2 of Set 8 | dosso
# Processing Record 3 of Set 8 | pimentel
# Processing Record 4 of Set 8 | tsabong
# Processing Record 5 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 6 of Set 8 | ambilobe
# Processing Record 7 of Set 8 | pedro velho
# Processing Record 8 of Set 8 | kolvereid
# Processing Record 9 of Set 8 | salihorsk
# Processing Record 10 of Set 8 | poya
# Processing Record 11 of Set 8 | hagere hiywet
# Processing Record 12 of Set 8 | mahon
# Processing Record 13 of Set 8 | ostrovnoy
# Processing Record 14 of Set 8 | waingapu
# Processing Record 15 of Set 8 | san policarpo
# Processing Record 16 of Set 8 | meulaboh
# Processing Record 17 of Set 8 | cidreira
# Processing Record 18 of Set 8 | paka
# Processing Record 19 of Set 8 | mayumba
# Processing Record 20 of Set 8 | calnic
# Processing Record 21 of Set 8 | padang
# Processing Record 22 of Set 8 | goundam
# Processing Record 23 of Set 8 | esperance
# Processing Record 24 of Set 8 | flinders
# Processing Record 25 of Set 8 | yar-sale
# Processing Record 26 of Set 8 | itoman
# Processing Record 27 of Set 8 | villefranche-de-rouergue
# Processing Record 28 of Set 8 | barcelona
# Processing Record 29 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 8 | ayan
# Processing Record 31 of Set 8 | tornio
# Processing Record 32 of Set 8 | santa rosa
# Processing Record 33 of Set 8 | sainte-rose
# Processing Record 34 of Set 8 | tabora
# Processing Record 35 of Set 8 | turochak
# Processing Record 36 of Set 8 | grand forks
# Processing Record 37 of Set 8 | osypenko
# Processing Record 38 of Set 8 | ken caryl
# Processing Record 39 of Set 8 | havoysund
# Processing Record 40 of Set 8 | moratuwa
# Processing Record 41 of Set 8 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 42 of Set 8 | malanje
# Processing Record 43 of Set 8 | san jose
# Processing Record 44 of Set 8 | berlevag
# Processing Record 45 of Set 8 | sumenep
# Processing Record 46 of Set 8 | kieta
# Processing Record 47 of Set 8 | muzhi
# Processing Record 48 of Set 8 | goderich
# Processing Record 49 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 8 | bethel
# Processing Record 1 of Set 9 | ciras
# City not found. Skipping...
# Processing Record 2 of Set 9 | boquira
# Processing Record 3 of Set 9 | talakan
# Processing Record 4 of Set 9 | boueni
# Processing Record 5 of Set 9 | tyrma
# Processing Record 6 of Set 9 | moerewa
# Processing Record 7 of Set 9 | ayagoz
# Processing Record 8 of Set 9 | sur
# Processing Record 9 of Set 9 | bundaberg
# Processing Record 10 of Set 9 | ca mau
# Processing Record 11 of Set 9 | chuguyevka
# Processing Record 12 of Set 9 | ketchikan
# Processing Record 13 of Set 9 | saskylakh
# Processing Record 14 of Set 9 | saint-augustin
# Processing Record 15 of Set 9 | los llanos de aridane
# Processing Record 16 of Set 9 | longyearbyen
# Processing Record 17 of Set 9 | burnie
# Processing Record 18 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 9 | ballina
# Processing Record 20 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 21 of Set 9 | bilibino
# Processing Record 22 of Set 9 | beringovskiy
# Processing Record 23 of Set 9 | phalodi
# Processing Record 24 of Set 9 | sakit
# Processing Record 25 of Set 9 | podporozhye
# Processing Record 26 of Set 9 | agva
# City not found. Skipping...
# Processing Record 27 of Set 9 | riaba
# City not found. Skipping...
# Processing Record 28 of Set 9 | sobolevo
# Processing Record 29 of Set 9 | domoni
# Processing Record 30 of Set 9 | yuancheng
# Processing Record 31 of Set 9 | nuuk
# Processing Record 32 of Set 9 | mitu
# Processing Record 33 of Set 9 | khasan
# Processing Record 34 of Set 9 | mehamn
# Processing Record 35 of Set 9 | nome
# Processing Record 36 of Set 9 | bayana
# Processing Record 37 of Set 9 | conceicao do araguaia
# Processing Record 38 of Set 9 | candolim
# Processing Record 39 of Set 9 | namtsy
# Processing Record 40 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 41 of Set 9 | rio gallegos
# Processing Record 42 of Set 9 | saint george
# Processing Record 43 of Set 9 | moen
# Processing Record 44 of Set 9 | son la
# Processing Record 45 of Set 9 | basoko
# Processing Record 46 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 47 of Set 9 | kirovskiy
# Processing Record 48 of Set 9 | lerwick
# Processing Record 49 of Set 9 | crossville
# Processing Record 50 of Set 9 | alizai
# Processing Record 1 of Set 10 | minas
# Processing Record 2 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 10 | genhe
# Processing Record 4 of Set 10 | medea
# Processing Record 5 of Set 10 | batagay
# Processing Record 6 of Set 10 | nichinan
# Processing Record 7 of Set 10 | laguna de perlas
# Processing Record 8 of Set 10 | almeirim
# Processing Record 9 of Set 10 | progreso
# Processing Record 10 of Set 10 | lunca
# Processing Record 11 of Set 10 | dolinsk
# Processing Record 12 of Set 10 | great sankey
# Processing Record 13 of Set 10 | angra
# City not found. Skipping...
# Processing Record 14 of Set 10 | reconquista
# Processing Record 15 of Set 10 | ancud
# Processing Record 16 of Set 10 | skjervoy
# Processing Record 17 of Set 10 | porto walter
# Processing Record 18 of Set 10 | dallas
# Processing Record 19 of Set 10 | barra do bugres
# Processing Record 20 of Set 10 | waldoboro
# Processing Record 21 of Set 10 | tingrela
# City not found. Skipping...
# Processing Record 22 of Set 10 | verkhnevilyuysk
# Processing Record 23 of Set 10 | kirakira
# Processing Record 24 of Set 10 | nueva loja
# Processing Record 25 of Set 10 | tinskoy
# Processing Record 26 of Set 10 | novyy urengoy
# Processing Record 27 of Set 10 | kodinsk
# Processing Record 28 of Set 10 | bambanglipuro
# Processing Record 29 of Set 10 | yingzhong
# City not found. Skipping...
# Processing Record 30 of Set 10 | vannes
# Processing Record 31 of Set 10 | egvekinot
# Processing Record 32 of Set 10 | scottsboro
# Processing Record 33 of Set 10 | bengbu
# Processing Record 34 of Set 10 | calama
# Processing Record 35 of Set 10 | namatanai
# Processing Record 36 of Set 10 | karachi
# Processing Record 37 of Set 10 | chimoio
# Processing Record 38 of Set 10 | zaraza
# Processing Record 39 of Set 10 | estelle
# Processing Record 40 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 41 of Set 10 | russell
# Processing Record 42 of Set 10 | broome
# Processing Record 43 of Set 10 | urumqi
# Processing Record 44 of Set 10 | nizhnetroitskiy
# Processing Record 45 of Set 10 | mizdah
# Processing Record 46 of Set 10 | moron
# Processing Record 47 of Set 10 | tuy hoa
# Processing Record 48 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 10 | pahrump
# Processing Record 50 of Set 10 | camana
# Processing Record 1 of Set 11 | acarau
# Processing Record 2 of Set 11 | leshukonskoye
# Processing Record 3 of Set 11 | faanui
# Processing Record 4 of Set 11 | klaksvik
# Processing Record 5 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 11 | san vicente
# Processing Record 7 of Set 11 | mount gambier
# Processing Record 8 of Set 11 | san lorenzo
# Processing Record 9 of Set 11 | slavonice
# Processing Record 10 of Set 11 | normandin
# Processing Record 11 of Set 11 | touros
# Processing Record 12 of Set 11 | traverse city
# Processing Record 13 of Set 11 | kismayo
# Processing Record 14 of Set 11 | winschoten
# Processing Record 15 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 11 | altamira
# Processing Record 17 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 18 of Set 11 | gawler
# Processing Record 19 of Set 11 | pombas
# Processing Record 20 of Set 11 | digoin
# Processing Record 21 of Set 11 | moses lake
# Processing Record 22 of Set 11 | kosh-agach
# Processing Record 23 of Set 11 | cambridge
# Processing Record 24 of Set 11 | rocha
# Processing Record 25 of Set 11 | safaqis
# City not found. Skipping...
# Processing Record 26 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 11 | providencia
# Processing Record 28 of Set 11 | grand gaube
# Processing Record 29 of Set 11 | rottenmann
# Processing Record 30 of Set 11 | mpanda
# Processing Record 31 of Set 11 | zhanakorgan
# Processing Record 32 of Set 11 | sarahan
# Processing Record 33 of Set 11 | manakara
# Processing Record 34 of Set 11 | oussouye
# Processing Record 35 of Set 11 | morales
# Processing Record 36 of Set 11 | northam
# Processing Record 37 of Set 11 | kozhevnikovo
# Processing Record 38 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 39 of Set 11 | muli
# Processing Record 40 of Set 11 | unhel
# Processing Record 41 of Set 11 | chillicothe
# Processing Record 42 of Set 11 | zhezkazgan
# Processing Record 43 of Set 11 | taksimo
# Processing Record 44 of Set 11 | truro
# Processing Record 45 of Set 11 | faya
# Processing Record 46 of Set 11 | ayabe
# Processing Record 47 of Set 11 | priyutnoye
# Processing Record 48 of Set 11 | tongzi
# Processing Record 49 of Set 11 | nanortalik
# Processing Record 50 of Set 11 | baruun-urt
# Processing Record 1 of Set 12 | fukue
# Processing Record 2 of Set 12 | presidente medici
# Processing Record 3 of Set 12 | buin
# Processing Record 4 of Set 12 | raga
# Processing Record 5 of Set 12 | jawhar
# Processing Record 6 of Set 12 | matucana
# Processing Record 7 of Set 12 | kununurra
# Processing Record 8 of Set 12 | noumea
# Processing Record 9 of Set 12 | velika gorica
# Processing Record 10 of Set 12 | ayaviri
# Processing Record 11 of Set 12 | santa helena
# Processing Record 12 of Set 12 | toba
# Processing Record 13 of Set 12 | yingcheng
# Processing Record 14 of Set 12 | richards bay
# Processing Record 15 of Set 12 | katherine
# Processing Record 16 of Set 12 | wahiawa
# Processing Record 17 of Set 12 | tual
# Processing Record 18 of Set 12 | kiama
# Processing Record 19 of Set 12 | pochutla
# Processing Record 20 of Set 12 | puerto colombia
# Processing Record 21 of Set 12 | monywa
# Processing Record 22 of Set 12 | bosaso
# Processing Record 23 of Set 12 | rupert
# Processing Record 24 of Set 12 | solnechnyy
# Processing Record 25 of Set 12 | catamarca
# Processing Record 26 of Set 12 | vardo
# Processing Record 27 of Set 12 | huilong
# Processing Record 28 of Set 12 | visnes
# Processing Record 29 of Set 12 | olenino
# Processing Record 30 of Set 12 | rosarito
# Processing Record 31 of Set 12 | malaut
# Processing Record 32 of Set 12 | abu samrah
# Processing Record 33 of Set 12 | uige
# Processing Record 34 of Set 12 | iralaya
# Processing Record 35 of Set 12 | urusha
# Processing Record 36 of Set 12 | pachino
# Processing Record 37 of Set 12 | achisay
# City not found. Skipping...
# Processing Record 38 of Set 12 | tanout
# Processing Record 39 of Set 12 | taiyuan
# Processing Record 40 of Set 12 | suntar
# Processing Record 41 of Set 12 | suratgarh
# Processing Record 42 of Set 12 | sangar
# Processing Record 43 of Set 12 | hasaki
# Processing Record 44 of Set 12 | dunnville
# Processing Record 45 of Set 12 | turukhansk
# Processing Record 46 of Set 12 | ghatampur
# Processing Record 47 of Set 12 | mayya
# Processing Record 48 of Set 12 | maxixe
# Processing Record 49 of Set 12 | beaverlodge
# Processing Record 50 of Set 12 | chkalovskoye
# Processing Record 1 of Set 13 | kurmanayevka
# Processing Record 2 of Set 13 | feijo
# Processing Record 3 of Set 13 | japura
# Processing Record 4 of Set 13 | tuatapere
# Processing Record 5 of Set 13 | sabha
# Processing Record 6 of Set 13 | narkevychi
# Processing Record 7 of Set 13 | linda
# Processing Record 8 of Set 13 | severo-yeniseyskiy
# Processing Record 9 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 13 | havelock
# Processing Record 11 of Set 13 | san rafael
# Processing Record 12 of Set 13 | mackay
# Processing Record 13 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 14 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 13 | codajas
# Processing Record 16 of Set 13 | haverfordwest
# Processing Record 17 of Set 13 | hurghada
# Processing Record 18 of Set 13 | conselheiro pena
# Processing Record 19 of Set 13 | san quintin
# Processing Record 20 of Set 13 | yushu
# Processing Record 21 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 22 of Set 13 | kenai
# Processing Record 23 of Set 13 | pandan
# Processing Record 24 of Set 13 | aswan
# Processing Record 25 of Set 13 | villa carlos paz
# Processing Record 26 of Set 13 | maridi
# Processing Record 27 of Set 13 | axim
# Processing Record 28 of Set 13 | abha
# Processing Record 29 of Set 13 | fare
# Processing Record 30 of Set 13 | asau
# Processing Record 31 of Set 13 | fria
# Processing Record 32 of Set 13 | malkangiri
# Processing Record 33 of Set 13 | san jeronimo
# Processing Record 34 of Set 13 | carmo do paranaiba
# Processing Record 35 of Set 13 | mahanoro
# Processing Record 36 of Set 13 | erenhot
# Processing Record 37 of Set 13 | san antonio
# Processing Record 38 of Set 13 | oistins
# Processing Record 39 of Set 13 | alekseyevka
# Processing Record 40 of Set 13 | east brunswick
# Processing Record 41 of Set 13 | wajima
# Processing Record 42 of Set 13 | deh rawud
# City not found. Skipping...
# Processing Record 43 of Set 13 | zima
# Processing Record 44 of Set 13 | gweta
# Processing Record 45 of Set 13 | jales
# Processing Record 46 of Set 13 | bang saphan
# Processing Record 47 of Set 13 | atikokan
# Processing Record 48 of Set 13 | mondlo
# Processing Record 49 of Set 13 | brasilia
# Processing Record 50 of Set 13 | tambilil
# Processing Record 1 of Set 14 | kulhudhuffushi
# Processing Record 2 of Set 14 | conde
# Processing Record 3 of Set 14 | barra patuca
# Processing Record 4 of Set 14 | jacareacanga
# Processing Record 5 of Set 14 | seydi
# Processing Record 6 of Set 14 | kawalu
# Processing Record 7 of Set 14 | te anau
# Processing Record 8 of Set 14 | storsteinnes
# Processing Record 9 of Set 14 | ardakan
# Processing Record 10 of Set 14 | mulege
# Processing Record 11 of Set 14 | coihaique
# Processing Record 12 of Set 14 | chake chake
# Processing Record 13 of Set 14 | kyzyl-suu
# Processing Record 14 of Set 14 | podyuga
# Processing Record 15 of Set 14 | samarai
# Processing Record 16 of Set 14 | christchurch
# Processing Record 17 of Set 14 | sarangani
# Processing Record 18 of Set 14 | shaowu
# Processing Record 19 of Set 14 | lodja
# Processing Record 20 of Set 14 | alofi
# Processing Record 21 of Set 14 | carauari
# Processing Record 22 of Set 14 | jacqueville
# Processing Record 23 of Set 14 | la palma
# Processing Record 24 of Set 14 | fort nelson
# Processing Record 25 of Set 14 | nkayi
# Processing Record 26 of Set 14 | permet
# Processing Record 27 of Set 14 | nemuro
# Processing Record 28 of Set 14 | lalmohan
# Processing Record 29 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 30 of Set 14 | kaspiysk
# Processing Record 31 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 14 | daru
# Processing Record 33 of Set 14 | lufilufi
# Processing Record 34 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 14 | kremenchuk
# Processing Record 36 of Set 14 | port pirie
# Processing Record 37 of Set 14 | toumodi
# Processing Record 38 of Set 14 | borova
# Processing Record 39 of Set 14 | kabo
# Processing Record 40 of Set 14 | novokruchininskiy
# Processing Record 41 of Set 14 | omsukchan
# Processing Record 42 of Set 14 | makat
# Processing Record 43 of Set 14 | chapais
# Processing Record 44 of Set 14 | ulladulla
# Processing Record 45 of Set 14 | mangan
# Processing Record 46 of Set 14 | shumikha
# Processing Record 47 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 48 of Set 14 | mangrol
# Processing Record 49 of Set 14 | bestobe
# Processing Record 50 of Set 14 | kenora
# Processing Record 1 of Set 15 | carahue
# Processing Record 2 of Set 15 | sungairaya
# Processing Record 3 of Set 15 | neiafu
# Processing Record 4 of Set 15 | rapar
# Processing Record 5 of Set 15 | dunedin
# Processing Record 6 of Set 15 | angoram
# Processing Record 7 of Set 15 | luau
# Processing Record 8 of Set 15 | shchelyayur
# City not found. Skipping...
# Processing Record 9 of Set 15 | teguise
# Processing Record 10 of Set 15 | port augusta
# Processing Record 11 of Set 15 | caravelas
# Processing Record 12 of Set 15 | panaba
# Processing Record 13 of Set 15 | alta floresta
# Processing Record 14 of Set 15 | marsa matruh
# Processing Record 15 of Set 15 | vyazma
# Processing Record 16 of Set 15 | yamada
# Processing Record 17 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 15 | taburao
# City not found. Skipping...
# Processing Record 19 of Set 15 | kjollefjord
# Processing Record 20 of Set 15 | santiago del estero
# Processing Record 21 of Set 15 | governador valadares
# Processing Record 22 of Set 15 | valenca do piaui
# Processing Record 23 of Set 15 | bajmok
# Processing Record 24 of Set 15 | goiania
# Processing Record 25 of Set 15 | port hardy
# Processing Record 26 of Set 15 | san carlos de bariloche
# Processing Record 27 of Set 15 | hami
# Processing Record 28 of Set 15 | sembakung
# Processing Record 29 of Set 15 | novo aripuana
# Processing Record 30 of Set 15 | nanzhou
# Processing Record 31 of Set 15 | bassila
# Processing Record 32 of Set 15 | north bend
# Processing Record 33 of Set 15 | puri
# Processing Record 34 of Set 15 | coxim
# Processing Record 35 of Set 15 | rugby
# Processing Record 36 of Set 15 | turka
# Processing Record 37 of Set 15 | wanning
# Processing Record 38 of Set 15 | saint-pierre
# Processing Record 39 of Set 15 | boa vista
# Processing Record 40 of Set 15 | gamba
# Processing Record 41 of Set 15 | dvinskoy
# Processing Record 42 of Set 15 | sunrise manor
# Processing Record 43 of Set 15 | mutare
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Sioux Lookout      CA  50.1001  -91.9170     -1.82        65          20
# 1           Avarua      CK -21.2078 -159.7750     82.45        83          20
# 2          Ushuaia      AR -54.8000  -68.3000     51.42        76          75
# 3             Hovd      MN  48.0056   91.6419     -4.00        92         100
# 4          Aklavik      CA  68.2191 -135.0107     -9.40        64          75
# 5         Olafsvik      IS  64.8945  -23.7142     40.32        97         100
# 6           Garowe      SO   8.4054   48.4845     66.06        76         100
# 7      Port Alfred      ZA -33.5906   26.8910     71.92        88          61
# 8             Naze      JP  28.3667  129.4833     59.92        80          88
# 9  Bambous Virieux      MU -20.3428   57.7575     75.45        83          40
#
#    Wind Speed Current Description
# 0        3.44          few clouds
# 1       17.27          few clouds
# 2       16.11       broken clouds
# 3        2.33     overcast clouds
# 4        5.75       broken clouds
# 5       26.96     overcast clouds
# 6        8.23     overcast clouds
# 7       13.62       broken clouds
# 8        9.64     overcast clouds
# 9        3.44    scattered clouds

# %%
# Turn file into csv and export dataframe
city_data_df.to_csv("WeatherPy_database.csv")
